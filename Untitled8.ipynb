# %% [markdown]
# <a href="https://colab.research.google.com/github/Someshkotni/DO180-apps/blob/master/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst=[1,2,3]
flag=0
subset=[]
for i in range(lst):
  flag=
